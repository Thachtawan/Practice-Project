# %%
savingAccount = float(0)

def atmFunction(account):
  menu = int(input("Please select your transaction (1-4): "))
  while menu > 4 or menu < 1:
    print("Wrong order please try again!")
    menu = int(input("Please select your transaction (1-4): "))

  amount = float(input("Please enter the amount of the transaction: "))
  while menu > int(4) or menu < int(4):
    if menu == int(1):
      account += amount
      print("You have deposited the amount of ", amount, " THB")
      print("Your current balance is ", account, " THB.")
    elif menu == int(2):
      if amount > account:
        print("You can't withdraw with the amount greater than your balance. Please try again.")
      else:
        account -= amount
        print("You have withdrawn the amount of ", amount, " THB.")
        print("Your current balance is ", account, " THB.")
    elif menu == int(3):
      print("Your current balance is ", account, "THB")

    menu = int(input("Do you want to do your next transaction?(press 4 if not): "))
    if menu == 3:
      continue
    elif menu == 4:
      print("Thank you for using our services!")
    elif menu == 1 or menu == 2:
      amount = int(input("Please enter the amount of the transaction: "))
    else:
      print("Wrong order please try again!")
  
atmFunction(savingAccount)
# Out:
# Please select your transaction (1-4): 5
# Wrong order please try again!
# Please select your transaction (1-4): 1
# Please enter the amount of the transaction: 1000
# You have deposited the amount of  1000.0  THB
# Your current balance is  1000.0  THB.
# Do you want to do your next transaction?(press 4 if not): 3
# Your current balance is  1000.0 THB
# Do you want to do your next transaction?(press 4 if not): 2
# Please enter the amount of the transaction: 2000
# You can't withdraw with the amount greater than your balance. Please try again.
# Do you want to do your next transaction?(press 4 if not): 5
# Wrong order please try again!
# Do you want to do your next transaction?(press 4 if not): 2
# Please enter the amount of the transaction: 200
# You have withdrawn the amount of  200  THB.
# Your current balance is  800.0  THB.
# Do you want to do your next transaction?(press 4 if not): 4
# Thank you for using our services!
