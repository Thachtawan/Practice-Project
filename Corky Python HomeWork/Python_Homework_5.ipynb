# %%
studentRoll = ["Kit", "Heart", "Wave", "Ton", "Fai", "Meow"]
searchValue = input("Who do you want to search for?: ")
if searchValue in studentRoll:
  print(searchValue, " is already in the list.")
else:
  print(searchValue, " is not in the list.")
# Out:
# Who do you want to search for?: Kit
# Kit  is already in the list.

# %%
studentRoll = ["Kit", "Heart", "Wave", "Ton", "Fai", "Meow"]
searchValue = input("Who do you want to search for?: ")
if searchValue in studentRoll:
  print(searchValue, " is already in the list.")
else:
  print(searchValue, " is not in the list.")
# Out:
# Who do you want to search for?: Chai
# Chai  is not in the list.
